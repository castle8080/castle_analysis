# %% [markdown]
# # ReadExtractIMDBTitleInfo

# %%
import os
import re
import urllib
import tarfile
import sqlite3
import gzip
import csv

import pandas as pd

# %% [markdown]
# ## Download Data

# %%
os.makedirs("var", exist_ok=True)

# %%
data_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
local_file = "var/title.basics.tsv.gz"

# %%
if not(os.path.isfile(local_file)):
    urllib.request.urlretrieve(data_url, local_file)

# %% [markdown]
# ## Load Data

# %%
title_info = pd.read_csv(local_file, sep='\t', encoding='utf-8', na_values=['\\N'], quoting=csv.QUOTE_NONE)

# %%
title_info.sample(5)
# Out:
#              tconst  titleType  \
# 7204868   tt6437316      short
# 1634985  tt11193208  tvEpisode
# 6984716   tt5943638  tvEpisode
# 5736532   tt3110852  tvEpisode
# 2276283  tt12349736      short
#
#                                               primaryTitle  \
# 7204868                                         The Moment
# 1634985                               PIZZAMAS IS HERE!!!!
# 6984716                      Your Vibe Attracts Your Tribe
# 5736532  The Evolution of Funny: TV Comedy with Larry W...
# 2276283                                    Licença Poética
#
#                                              originalTitle  isAdult  \
# 7204868                                         The Moment        0
# 1634985                               PIZZAMAS IS HERE!!!!        0
# 6984716                      Your Vibe Attracts Your Tribe        0
# 5736532  The Evolution of Funny: TV Comedy with Larry W...        0
# 2276283                                    Licença Poética        0
#
#          startYear  endYear  runtimeMinutes                    genres
# 7204868     2016.0      NaN             2.0     Animation,Drama,Short
# 1634985     2019.0      NaN             NaN  Comedy,Documentary,Music
# 6984716     2016.0      NaN            11.0                    Comedy
# 5736532     2013.0      NaN            27.0                 Talk-Show
# 2276283     2019.0      NaN            13.0                     Short

# %%
title_info.isAdult.value_counts().to_frame()
# Out:
#    isAdult
# 0  8527053
# 1   272365

# %%
title_info.titleType.value_counts().to_frame()
# Out:
#               titleType
# tvEpisode       6594590
# short            862074
# movie            605618
# video            258503
# tvSeries         222707
# tvMovie          135520
# tvMiniSeries      42742
# tvSpecial         36408
# videoGame         30742
# tvShort           10512
# tvPilot               2

# %%
title_info.startYear.value_counts().to_frame()
# Out:
#         startYear
# 2018.0     411707
# 2017.0     409565
# 2019.0     396631
# 2016.0     389624
# 2021.0     384671
# ...           ...
# 1882.0          2
# 1881.0          2
# 1874.0          1
# 1883.0          1
# 1885.0          1
#
# [150 rows x 1 columns]

# %%
title_info = title_info.rename(columns={'tconst': 'titleId'})

# %%
title_info
# Out:
#            titleId  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 8799413  tt9916848  tvEpisode              Episode #3.17
# 8799414  tt9916850  tvEpisode              Episode #3.19
# 8799415  tt9916852  tvEpisode              Episode #3.20
# 8799416  tt9916856      short                   The Wind
# 8799417  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0                       Carmencita        0     1894.0      NaN
# 1           Le clown et ses chiens        0     1892.0      NaN
# 2                   Pauvre Pierrot        0     1892.0      NaN
# 3                      Un bon bock        0     1892.0      NaN
# 4                 Blacksmith Scene        0     1893.0      NaN
# ...                            ...      ...        ...      ...
# 8799413              Episode #3.17        0     2010.0      NaN
# 8799414              Episode #3.19        0     2010.0      NaN
# 8799415              Episode #3.20        0     2010.0      NaN
# 8799416                   The Wind        0     2015.0      NaN
# 8799417  Horrid Henry Knows It All        0     2014.0      NaN
#
#          runtimeMinutes                      genres
# 0                   1.0           Documentary,Short
# 1                   5.0             Animation,Short
# 2                   4.0    Animation,Comedy,Romance
# 3                  12.0             Animation,Short
# 4                   1.0                Comedy,Short
# ...                 ...                         ...
# 8799413             NaN         Action,Drama,Family
# 8799414             NaN         Action,Drama,Family
# 8799415             NaN         Action,Drama,Family
# 8799416            27.0                       Short
# 8799417            10.0  Adventure,Animation,Comedy
#
# [8799418 rows x 9 columns]

# %% [markdown]
# ## Save to DB

# %%
db = sqlite3.connect("var/reviews.db")

# %%
title_info.to_sql('titles', if_exists='replace', index=False, chunksize=5000, con=db)

# %%
db.commit()

# %%
db.execute("create unique index i_titles_pk on titles (titleId)")
db.commit()

# %%
db.close()
