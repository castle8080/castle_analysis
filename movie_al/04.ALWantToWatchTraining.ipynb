# %% [markdown]
# # Train Model to Find Movies I Want to Watch
#
# https://github.com/modAL-python/modAL

# %%
import os
import re
import urllib
import tarfile
import sqlite3
import spacy
import logging
import sys
import json
import pickle

import pandas as pd
import numpy as np

import modAL
from modAL.models import ActiveLearner
from modAL.uncertainty import uncertainty_sampling, entropy_sampling
from modAL.density import information_density

from sklearn.ensemble import RandomForestClassifier

from IPython.display import display, clear_output, HTML, JSON

# %% [markdown]
# ## Config

# %%
reviews_db = "var/reviews.db"
label_table = "watch_labels"

# %% [markdown]
# ## Load Data

# %%
db = sqlite3.connect(reviews_db)

# %%
pd.read_sql("select * from sqlite_master", db)
# Out:
#     type                    name           tbl_name  rootpage  \
# 0  table                  titles             titles     43150
# 1  index             i_titles_pk             titles    232137
# 2  table                 reviews            reviews         2
# 3  index            i_reviews_pk            reviews     39667
# 4  index      i_reviews_title_id            reviews     40748
# 5  table       review_embeddings  review_embeddings     41181
# 6  index  i_review_embeddings_pk  review_embeddings    303627
# 7  table            watch_labels       watch_labels    303908
# 8  index      ix_watch_labels_id       watch_labels    303909
#
#                                                  sql
# 0  CREATE TABLE "titles" (\n"titleId" TEXT,\n  "t...
# 1  CREATE UNIQUE INDEX i_titles_pk on titles (tit...
# 2  CREATE TABLE "reviews" (\n"id" INTEGER,\n  "ti...
# 3   CREATE UNIQUE INDEX i_reviews_pk on reviews (id)
# 4  CREATE INDEX i_reviews_title_id on reviews (ti...
# 5  CREATE TABLE "review_embeddings" (\n"id" INTEG...
# 6  CREATE UNIQUE INDEX i_review_embeddings_pk on ...
# 7  CREATE TABLE "watch_labels" (\n"id" INTEGER,\n...
# 8  CREATE INDEX "ix_watch_labels_id"ON "watch_lab...

# %%
reviews = pd.read_sql("""
    select
        r.*,
        e.review_embedding
    from reviews r
    left join review_embeddings e on (e.id = r.id)
""", db)

# %%
reviews['review_embedding'] = reviews.review_embedding.apply(lambda et: np.array(json.loads(et)))

# %%
reviews.sample(5)
# Out:
#           id    titleId dataset  class  datasetclassId  rating  \
# 33515  33516  tt0216196   train    neg            8508       1
# 68044  68045  tt0238883   train  unsup           17923       0
# 81901  81902  tt0082348   train  unsup           31970       0
# 79097  79098  tt0127751   train  unsup           29142       0
# 76573  76574  tt0015400   train  unsup           26546       0
#
#                                                   review  \
# 33515  It was agonizingly bad movie. It will eat your...
# 68044  This film is not a spook for Americans. Don't ...
# 81901  Along with Ken Russell, John Boorman can be se...
# 79097  How do these movies get made? Asinine script, ...
# 76573  "The Thief of Bagdad" (1924) is an amazing adv...
#
#                                         review_embedding
# 33515  [-0.7727392315864563, 0.3622419536113739, -0.1...
# 68044  [-0.38934630155563354, 0.4539123475551605, -0....
# 81901  [-0.1836564689874649, 0.21428164839744568, 0.0...
# 79097  [-0.529217004776001, 0.3868107497692108, -0.18...
# 76573  [-0.280286580324173, 0.3886405825614929, -0.14...

# %%
titles = pd.read_sql("""
    select *
    from titles t
    where
        t.titleId in (
            select titleId
            from reviews
        )
""", db)

# %%
titles.sample(5)
# Out:
#         titleId     titleType                primaryTitle  \
# 8618  tt0248808         short               For the Birds
# 288   tt0022614         movie          The Age of Consent
# 5893  tt0111931  tvMiniSeries                    Crusades
# 7170  tt0144555         movie  Premutos: The Fallen Angel
# 9853  tt0331509         movie                Funky Monkey
#
#                        originalTitle  isAdult  startYear  endYear  \
# 8618                   For the Birds        0     2000.0      NaN
# 288               The Age of Consent        0     1932.0      NaN
# 5893                        Crusades        0     1995.0   1995.0
# 7170  Premutos - Der gefallene Engel        0     1997.0      NaN
# 9853                    Funky Monkey        0     2004.0      NaN
#
#       runtimeMinutes                   genres
# 8618             3.0  Animation,Comedy,Family
# 288             63.0            Drama,Romance
# 5893           200.0  Documentary,History,War
# 7170           106.0            Comedy,Horror
# 9853            94.0            Comedy,Family

# %%
reviews = pd.merge(
    reviews,
    titles[['titleId', 'titleType', 'primaryTitle', 'genres', 'startYear']],
    on=['titleId'],
    how = 'left'
)

# %%
reviews.titleType.value_counts().to_frame()
# Out:
#               titleType
# movie             74832
# tvMovie            5792
# video              4863
# tvSeries           4134
# short              1682
# tvMiniSeries       1469
# tvEpisode          1236
# videoGame           385
# tvSpecial           320
# tvShort              60

# %%
# I want to limit this to movies
reviews = reviews[reviews.titleType.isin({'movie', 'tvMovie'})]

# %%
len(reviews)
# Out:
# 80624

# %%
reviews = reviews.set_index('id')

# %% [markdown]
# ## Active Learning Code Modules

# %% [markdown]
# ### Label Management
#
# Responsible for updating and retrieving labels.

# %%
class LabelManagement:
    
    def __init__(self, db, label_table, reviews):
        self.db = db
        self.label_table = label_table
        self.reviews = reviews
        self.initialize()
        
    def initialize(self):
        self.initialize_label_table()
        self.load_labels()
        self.update_pool_and_training()
        
    def clear_labels(self):
        self.db.execute(f"delete from {self.label_table}")
        self.db.commit()
        self.update_pool_and_training()
        
    def initialize_label_table(self):
        lbl_table_count = pd.read_sql(
            "select count(*) as Count from sqlite_master where type = 'table' and name = ?",
            self.db,
            params=[self.label_table]
        ).iloc[0].Count

        if lbl_table_count < 1:
            self.db.execute(f"""
                create table {self.label_table} (
                    id varchar(100) not null primary key,
                    wanted int not null
                )
            """)
            self.db.commit()
         
    def save_labels(self):
        self.labels.to_sql(label_table, db, if_exists = 'replace')
        self.db.execute(f"""
            create unique index i_{self.label_table}_pk on {self.label_table} (id)
        """)
        self.db.commit()
        
    def load_labels(self):
        self.labels = pd.read_sql(f"select * from {self.label_table}", self.db)
        self.labels = self.labels.set_index('id')
        return self.labels
        
    def update_pool_and_training(self):
        labelled_ids = set(self.labels.index.values)
        self.pool = self.reviews[~self.reviews.index.isin(labelled_ids)]
        self.train = self.reviews[self.reviews.index.isin(labelled_ids)]
        
        self.x_pool = np.vstack(self.pool.review_embedding)
        self.x_pool_ids = self.pool.index.values
        
        if len(self.train) > 0:
            self.x_train = np.vstack(self.train.review_embedding)
            self.x_train_ids = self.train.index.values
            self.y_train = self.labels.loc[self.x_train_ids].wanted.values
        else:
            self.x_train = None
            self.x_train_ids = None
            self.y_train = None
        
    def add_labels(self, idxs, results):
        self.labels = pd.concat([self.labels, pd.DataFrame({'id': self.x_pool_ids[idxs], 'wanted': results}).set_index('id')])
        self.update_pool_and_training()
        
lbl_manager = LabelManagement(db, label_table, reviews)

# %%
lbl_manager.labels
# Out:
# Empty DataFrame
# Columns: [wanted]
# Index: []

# %%
# Run the line below to clear out previous labels

#lbl_manager.clear_labels()

# %% [markdown]
# ### LabelUI
#
# Responsible for handling basic input interactions with the user to obtain labels.

# %%
class LabelUI:
    def __init__(self, lbl_manager):
        self.lbl_manager = lbl_manager
        
    def query_wanted(self, pool_idx):
        while True:
            #clear_output()
            r_id = self.lbl_manager.x_pool_ids[pool_idx]
            r = self.lbl_manager.reviews.loc[r_id]
            print(r.review)
            print("\n")
            print("Do you want to watch this? [y/n]")

            ans = input().lower().strip()
            if ans == 'y':
                return 1
            elif ans == 'n':
                return 0

    def query_batch(self, idxs):
        results = [self.query_wanted(idx) for idx in idxs]
        x = self.lbl_manager.x_pool[idxs]
        self.lbl_manager.add_labels(idxs, results)
        return (x, idxs, results)

    def query_random(self, n):
        idxs = pd.Series(range(0, len(self.lbl_manager.x_pool_ids))).sample(n).values
        return self.query_batch(idxs)

lbl_ui = LabelUI(lbl_manager)

# %% [markdown]
# ### ActiveLearnerDriver
#
# Responsible for putting the label management and UI together to drive the overall experience of labelling.

# %%
class ActiveLearnerDriver:
    
    def __init__(self, learner, lbl_ui):
        self.lbl_ui = lbl_ui
        self.learner = learner
        
    def query_random(self, n):
        lbl_ui.query_random(n)
        lbl_manager = self.lbl_ui.lbl_manager
        learner.teach(lbl_manager.x_train, lbl_manager.y_train.astype(bool))
        lbl_manager.save_labels()
        
    def query_n(self, n):
        lbl_manager = self.lbl_ui.lbl_manager
        for round in range(0, n):
            query_idx, query_inst = learner.query(lbl_manager.x_pool)
            print(f"idx: {query_idx}")
            x, ids, results = lbl_ui.query_batch(query_idx)
            learner.teach(x, np.array(results).astype(bool), only_new=False)
        lbl_manager.save_labels()

# %% [markdown]
# ## Active Learner Setup
#
# Create and setup the active learner.

# %%
def sampling_factory(al, x):
    return entropy_sampling(al, x, n_instances=1, random_tie_break=True)
    
model = RandomForestClassifier()

learner = ActiveLearner(
    estimator = model,
    query_strategy = sampling_factory
)

al_driver = ActiveLearnerDriver(learner, lbl_ui)

# %% [markdown]
# ## Get Labels
# The cell below well figure out which label to get next, prompt you for a label, and save the results.

# %%
al_driver.query_n(1)
# Out:
# idx: [10746]
# Why couldn't the end of the movie have been Sean Connery's men fighting the French instead of the Germans. Ever since the French had occupied Algeria in 1830, the tribes from Morocco and those of Algeria were making raids on the French military and civilian settlements. This movie could have been a continuous of that historical aspect where the French had seize the Rasuadli so his followers would not be raiding Algeria, and then his followers would have attacked the French to free him.<br /><br />The movie is still stereotypical of shootouts between the Germans and the Americans. When the Americans shoot the Germans, their guns (even the pistols) make loud noises, create large bloody bullet wounds, and their enemies are screaming after being shot. When Germans shoot at the Americans, their guns don't make large sounds, do not create bloody wounds, and their enemies make little or no sound after being shot.<br /><br />In real life, the American Krag rifle was the worst rifle America had ever produce until the early version of the M-16 came along. The Krag was hard to maintain, not reliable, and the rifle bolt was always jamming. The German Mauser was one of the world's finest rifles. We were so impress by it during Spanish American war, that we made a copy of it and call it the Springfield rifle.<br /><br />Finally, the people of Morocco must had a word for artillery since the French were using them in their raids against Morocco. I didn't like it when they made the Rasuldai feel stupid that there was no word for artillery in the Moorican vocabulary. Instead, the Rasuadli stated that the Europeans had guns on wheels that make the ground shake.
#
#
# Do you want to watch this? [y/n]
#  n

# %%
# As you label you can see the feature importances change
model.feature_importances_
# Out:
# array([0.01355946, 0.02373175, 0.02910919, 0.03849558, 0.02699647,
#        0.01590186, 0.00718273, 0.01536253, 0.01551587, 0.01131622,
#        0.02285567, 0.02246399, 0.02100886, 0.01961654, 0.03957821,
#        0.0201633 , 0.01419334, 0.00970113, 0.02099284, 0.00951679,
#        0.01578759, 0.01269281, 0.01086385, 0.01494053, 0.01931959,
#        0.01496078, 0.01366419, 0.02176921, 0.01315825, 0.01411886,
#        0.02397039, 0.02360592, 0.03394227, 0.01255319, 0.0110483 ,
#        0.01911003, 0.01683718, 0.02444243, 0.01915044, 0.01719118,
#        0.01454655, 0.03425428, 0.02947425, 0.01121916, 0.01335979,
#        0.00820798, 0.01313291, 0.07836225, 0.01848191, 0.02857154])

# %%
# See how many labels we have in the db
pd.read_sql(f"select count(*) from {label_table}", db)
# Out:
#    count(*)
# 0       100

# %% [markdown]
# ### Get Predictions
#
# Using the model, get predictions about a review being compelling.

# %%
review_p = model.predict_proba(np.vstack(lbl_manager.reviews.review_embedding)).T
reviews_wp = lbl_manager.reviews.copy()
reviews_wp['bad_p'] = review_p[0]
reviews_wp['good_p'] = review_p[1]

reviews_wp = pd.merge(
    reviews_wp,
    lbl_manager.labels,
    how = 'left',
    left_index = True,
    right_index = True
)

reviews_wp = reviews_wp.sort_values(by='good_p', ascending=False)

# %% [markdown]
# ### Show top 20 movies to watch which weren't explicitlyl labelled.

# %%
reviews_wp[reviews_wp.wanted.isnull()][['primaryTitle', 'rating', 'genres', 'startYear', 'good_p', 'review']].head(20)
# Out:
#                                      primaryTitle  rating  \
# id
# 48802                                   Citizen X      10
# 98931                          The Gypsy Warriors       0
# 20533                          Cannon for Cordoba       8
# 21937                                   Crossfire       9
# 44524                              Winchester '73       9
# 76484                                  Apocalypto       0
# 12835                              Apocalypse Now      10
# 61517                                The Red Tent       0
# 53442                            1968 Tunnel Rats       0
# 53763                               The Vanishing       0
# 4332                        Partizanska eskadrila       4
# 56484                       In the Valley of Elah       0
# 38345  Star Wars: Episode VI - Return of the Jedi      10
# 59203                               Lust, Caution       0
# 85332                                  Gen-X Cops       0
# 13776                       The Wind and the Lion       9
# 74650                                   Wolf Lake       0
# 60458                                    Predator       0
# 63254                                     Red Sun       0
# 65595                            The Untouchables       0
#
#                          genres  startYear  good_p  \
# id
# 48802     Biography,Crime,Drama     1995.0    0.81
# 98931          Comedy,Drama,War     1978.0    0.81
# 20533    Action,Romance,Western     1970.0    0.80
# 21937     Crime,Drama,Film-Noir     1947.0    0.78
# 44524      Action,Drama,Western     1950.0    0.78
# 76484    Action,Adventure,Drama     2006.0    0.76
# 12835         Drama,Mystery,War     1979.0    0.76
# 61517           Adventure,Drama     1969.0    0.76
# 53442          Action,Drama,War     2008.0    0.76
# 53763          Mystery,Thriller     1988.0    0.76
# 4332          Drama,History,War     1979.0    0.76
# 56484       Crime,Drama,Mystery     2007.0    0.76
# 38345  Action,Adventure,Fantasy     1983.0    0.76
# 59203     Drama,History,Romance     2007.0    0.76
# 85332       Action,Comedy,Crime     1999.0    0.75
# 13776    Action,Adventure,Drama     1975.0    0.75
# 74650            Drama,Thriller     1980.0    0.75
# 60458   Action,Adventure,Horror     1987.0    0.75
# 63254            Action,Western     1971.0    0.75
# 65595      Crime,Drama,Thriller     1987.0    0.75
#
#                                                   review
# id
# 48802  CitizenX(1995) is the developing world's answe...
# 98931  In this uninspired, made-for-television, buddy...
# 20533  I have reasons to love the great users of a ca...
# 21937  Taut and organically gripping, Edward Dmytryk'...
# 44524  The larger-than-life figures of Wyatt Earp and...
# 76484  The Mel Gibson movie "Apocalypto" ranks as one...
# 12835  Movies seem to fall into two categories: films...
# 61517  atching THE RED TENT gave me that rare fulfill...
# 53442  What am I supposed to say about a war film mad...
# 53763  George Sluizer's magnificent European thriller...
# 4332   Throughout the 1950s and into the 60s, 70s and...
# 56484  'War is hell' but perhaps it is the postwar th...
# 38345  Despite the feelings of most "Star Wars" fans,...
# 59203  I can't think of a more prevalent example of m...
# 85332  GEN-X COPS (Te Jing Xin Ren Lei)<br /><br />As...
# 13776  1904. The North African nation of Morocco is h...
# 74650  A couple of middle aged war buddies led by Cha...
# 60458  John Mctierman and company have laid claim to ...
# 63254  In the late 1800's, Arizona. Two desperadoes L...
# 65595  Director Brian De Palma is the son of a surgeo...

# %%
# Show top 20 whether explictlyl labelled or not
reviews_wp[['primaryTitle', 'rating', 'genres', 'startYear', 'good_p', 'review', 'wanted']].head(20)
# Out:
#                     primaryTitle  rating                      genres  \
# id
# 50171           Ring 0: Birthday       0     Horror,Mystery,Thriller
# 15093      2001: A Space Odyssey      10            Adventure,Sci-Fi
# 68384     Somewhere in the Night       0       Crime,Drama,Film-Noir
# 80261                     Puzzle       0    Mystery,Romance,Thriller
# 63658                 Compañeros       0       Action,Comedy,Western
# 76940         Kiss of the Dragon       0       Action,Crime,Thriller
# 61200        Widow of St. Pierre       0       Drama,History,Romance
# 73552      Breaking and Entering       0         Crime,Drama,Romance
# 69268   Tears of the Black Tiger       0       Action,Comedy,Romance
# 72316                  Outlander       0     Action,Adventure,Sci-Fi
# 66035  Godzilla 2000: Millennium       0      Action,Adventure,Drama
# 15979           Any Gun Can Play       7    Action,Adventure,Western
# 82209     The Return of the King       0  Adventure,Animation,Family
# 38237              The Last Wave       7       Drama,Fantasy,Mystery
# 80473                   Gigantic       0                Comedy,Drama
# 74570                    Dhamaal       0     Action,Adventure,Comedy
# 21271                   Saboteur       8                Thriller,War
# 74662               Shoot 'Em Up       0      Action,Comedy,Thriller
# 12762       Strangers on a Train       9       Crime,Drama,Film-Noir
# 51530              The Black Cat       0      Adventure,Crime,Horror
#
#        startYear  good_p                                             review  \
# id
# 50171     2000.0    0.90  In Jôji Iida's "Rasen", Sadako explained that ...
# 15093     1968.0    0.90  2001: A Space Odyssey <br /><br />Is it a serm...
# 68384     1946.0    0.89  Borrowed as the title of Nicholas Christopher'...
# 80261     1974.0    0.87  Duccio Tessari's "L'Uomo Senza Memoria" (aka. ...
# 63658     1970.0    0.87  "Vamos A Matar, Compañeros" is another terrifi...
# 76940     2001.0    0.86  KISS OF THE DRAGON / (2001) *** (out of four) ...
# 61200     2000.0    0.86  Patrice LeConte colors this intelligent film i...
# 73552     2006.0    0.85  Jude Law plays Will, an architect who lives wi...
# 69268     2000.0    0.84  Tears of the Black Tiger is one of those films...
# 72316     2008.0    0.84  "Outlander" is a great surprise by director Ho...
# 66035     1999.0    0.84  <br /><br />This is the latest in the Toho Fil...
# 15979     1967.0    0.83  A train holding union soldiers is transporting...
# 82209     1980.0    0.83  It was the first time that Rankin/Bass had dar...
# 38237     1977.0    0.82  I remember seeing this when it was released, i...
# 80473     1999.0    0.82  At its beginning, Gigantic (English title) see...
# 74570     2007.0    0.82  After months and months of flops being release...
# 21271     1942.0    0.82  Saboteur is a 1942 film, partly aimed at getti...
# 74662     2007.0    0.82  Shoot Em' Up <br /><br />Are you tired of all ...
# 12762     1951.0    0.82  In Truffaut book-length interview with Hitchco...
# 51530     1934.0    0.81  A couple Peter and Joan Allison are joined by ...
#
#       wanted
# id
# 50171      1
# 15093      1
# 68384      1
# 80261      1
# 63658      1
# 76940      1
# 61200      1
# 73552      1
# 69268      1
# 72316      1
# 66035      1
# 15979      1
# 82209      1
# 38237      1
# 80473      1
# 74570      1
# 21271      1
# 74662      1
# 12762      1
# 51530      1

# %%
# Show worst 10
reviews_wp[['primaryTitle', 'rating', 'genres', 'startYear', 'good_p', 'review', 'wanted']].tail(10)
# Out:
#                    primaryTitle  rating                  genres  startYear  \
# id
# 77348   A Return to Salem's Lot       0  Comedy,Horror,Thriller     1987.0
# 19475           The Rain People       9                   Drama     1969.0
# 77830                 Twin Town       0            Comedy,Drama     1997.0
# 31711  Gentlemen Prefer Blondes       4  Comedy,Musical,Romance     1953.0
# 97751        The Anderson Tapes       0   Action,Crime,Thriller     1971.0
# 10937  The Quick and the Undead       1   Action,Horror,Western     2006.0
# 27158           The Groove Tube       2                  Comedy     1974.0
# 84530            200 Cigarettes       0    Comedy,Drama,Romance     1999.0
# 89173                  Sextette       0  Comedy,Musical,Romance     1977.0
# 96420      Kiss Daddy Goodnight       0                Thriller     1987.0
#
#        good_p                                             review wanted
# id
# 77348    0.03  It's hard to put into words just how bad the a...    NaN
# 19475    0.02  Newly-pregnant Knight bolts from husband for n...    NaN
# 77830    0.02  Dougray Scott has appeared in over a dozen mov...    NaN
# 31711    0.02  Evidently lots of people really like this, but...    NaN
# 97751    0.02  Veteran director Sidney Lumet has made many ab...    NaN
# 10937    0.02  Firstly, I am a huge fan of crap films. B grad...    NaN
# 27158    0.02  After two long, long opening skits, one of whi...    NaN
# 84530    0.02  Many critics thought the film "200 Cigarettes"...    NaN
# 89173    0.02  Okay, so I'm a big movie buff & I just HAD to ...    NaN
# 96420    0.02  This truly obscure neo-noir from 1988 is memor...    NaN

# %%
# Wanted to see how genres relate to chance of wanting to watch.

genres_good_p = (reviews_wp
    .groupby('genres')
    .agg({'good_p': ['mean', len]})
    .reset_index()
    .sort_values(by=[('good_p', 'mean')], ascending=False))

genres_good_p[genres_good_p[('good_p', 'len')] >= 20].head(20)
# Out:
#                          genres    good_p
#                                      mean  len
# 475           Drama,Mystery,War  0.398000   30
# 152      Adventure,Crime,Horror  0.386410   39
# 145        Adventure,Comedy,War  0.378000   30
# 567                Thriller,War  0.371154   52
# 373     Crime,Film-Noir,Romance  0.354333   30
# 518   Film-Noir,Horror,Thriller  0.352667   30
# 408     Documentary,History,War  0.350476   21
# 520  Film-Noir,Mystery,Thriller  0.345152   66
# 484            Drama,Sci-Fi,War  0.341667   30
# 431       Drama,Fantasy,History  0.339667   30
# 563             Romance,Western  0.339310   58
# 512      Fantasy,Mystery,Sci-Fi  0.337667   30
# 147             Adventure,Crime  0.332903   31
# 422        Drama,Family,History  0.327500   24
# 335          Comedy,Musical,War  0.325238   21
# 16         Action,Adventure,War  0.321860   43
# 407   Documentary,History,Sport  0.318286   35
# 359       Crime,Drama,Film-Noir  0.316957  736
# 69         Action,Drama,Western  0.315410   61
# 441             Drama,Film-Noir  0.315000   48

# %% [markdown]
# # Save Results

# %%
# Save results to csv.

movies_to_watch = reviews_wp[['titleId', 'primaryTitle', 'startYear', 'genres', 'review', 'good_p', 'rating']]
movies_to_watch.to_csv("var/movies_wanted.csv")

# %% [markdown]
# # Save Model

# %%
with open("var/models/wanted_review.pkl", "wb") as fh:
    pickle.dump(model, fh)
