# %% [markdown]
# # Artist Detail

# %%
# %run ./wikipedia_setup.ipynb

# %%
import gensim
from gensim.models.doc2vec import TaggedDocument, Doc2Vec

# %% [markdown]
# ## Configure DB and Data Accessors

# %%
db = sqlite3.Connection("var/data/music.db")

# %% [markdown]
# ## Explore

# %%
pd.read_sql("""
    select count(*)
    from artist
""", db)
# Out:
#    count(*)
# 0     11134

# %%
pd.read_sql("""
    select *
    from artist
    where
        (abs(random() % 10000000.0) / 10000000.0) <= 0.001
""", db)
# Out:
#                                                Artist  \
# 0                                        Duncan Sheik
# 1                                      Emilie Nicolas
# 2                                       Jeong Se-woon
# 3                                         John Popper
# 4                                          Judy Tzuke
# 5   Liar, Flower (KatieJane Garside and Chris Whit...
# 6                                              Magic!
# 7                                        Mallory Knox
# 8                                   Matthew Good Band
# 9                                             NCT 127
# 10                                        Queensrÿche
# 11                                       Slum Village
# 12                          The Asteroids Galaxy Tour
# 13                                           deadmau5
#
#                                            ArtistLink  \
# 0          https://en.wikipedia.org/wiki/Duncan_Sheik
# 1        https://en.wikipedia.org/wiki/Emilie_Nicolas
# 2         https://en.wikipedia.org/wiki/Jeong_Se-woon
# 3           https://en.wikipedia.org/wiki/John_Popper
# 4            https://en.wikipedia.org/wiki/Judy_Tzuke
# 5     https://en.wikipedia.org/wiki/KatieJane_Garside
# 6                https://en.wikipedia.org/wiki/Magic!
# 7          https://en.wikipedia.org/wiki/Mallory_Knox
# 8     https://en.wikipedia.org/wiki/Matthew_Good_Band
# 9               https://en.wikipedia.org/wiki/NCT_127
# 10     https://en.wikipedia.org/wiki/Queensr%C3%BFche
# 11         https://en.wikipedia.org/wiki/Slum_Village
# 12  https://en.wikipedia.org/wiki/The_Asteroids_Ga...
# 13             https://en.wikipedia.org/wiki/Deadmau5
#
#                                      ArtistDetailText
# 0   \n \n \n \n Duncan Sheik - Wikipedia \n \n \n ...
# 1   \n \n \n \n Emilie Nicolas - Wikipedia \n \n \...
# 2   \n \n \n \n Jeong Se-woon - Wikipedia \n \n \n...
# 3   \n \n \n \n John Popper - Wikipedia \n \n \n \...
# 4   \n \n \n \n Judie Tzuke - Wikipedia \n \n \n \...
# 5   \n \n \n \n KatieJane Garside - Wikipedia \n \...
# 6   \n \n \n \n Magic! - Wikipedia \n \n \n \n \n ...
# 7   \n \n \n \n Mallory Knox - Wikipedia \n \n \n ...
# 8   \n \n \n \n Matthew Good Band - Wikipedia \n \...
# 9   \n \n \n \n NCT 127 - Wikipedia \n \n \n \n \n...
# 10  \n \n \n \n Queensrÿche - Wikipedia \n \n \n \...
# 11  \n \n \n \n Slum Village - Wikipedia \n \n \n ...
# 12  \n \n \n \n The Asteroids Galaxy Tour - Wikipe...
# 13  \n \n \n \n Deadmau5 - Wikipedia \n \n \n \n \...

# %%
pd.read_sql("""
    select
      min(length(ArtistDetailText)),
      max(length(ArtistDetailText)),
      avg(length(ArtistDetailText)),
      sum(length(ArtistDetailText))
    from artist
""", db)
# Out:
#    min(length(ArtistDetailText))  max(length(ArtistDetailText))  \
# 0                           2634                         239184
#
#    avg(length(ArtistDetailText))  sum(length(ArtistDetailText))
# 0                   27635.887282                      307697969

# %%
artists = pd.read_sql("select * from artist", db)

# %%
ad_lens = artists.ArtistDetailText.apply(len)

plt.figure(figsize=(12, 4))
plt.title("Artist Detail Lengths")
plt.hist(ad_lens, bins=100)
plt.grid(1)
plt.show()

# %%
ad_lens.describe().to_frame()
# Out:
#        ArtistDetailText
# count      11134.000000
# mean       27635.887282
# std        26997.574700
# min         2634.000000
# 25%        11457.000000
# 50%        18969.500000
# 75%        33125.750000
# max       239184.000000

# %% [markdown]
# ## Process Words

# %%
artists['DetailWords'] = artists.ArtistDetailText.apply(DetailWords.get_words)

# %%
wc = WordCounter()
wc.add_docs(artists['DetailWords'])

# %%
word_info = wc.get_word_info()

# %%
word_info
# Out:
#                                     Word  WordCount  DocCount  WordPercent  \
# 0                                    the    2023735     11134     5.192111
# 1                                    and     863789     11134     2.216144
# 2                                     in     812073     11134     2.083461
# 3                                     of     735585     11134     1.887223
# 4                                     on     588987     11134     1.511110
# ...                                  ...        ...       ...          ...
# 363130                            uphaus          1         1     0.000003
# 363131                             thant          1         1     0.000003
# 363132                          benenson          1         1     0.000003
# 363133                            ennals          1         1     0.000003
# 363134  ≠me、メジャー1stシングルタイトル＆mv＆最新ビジュアル解禁          1         1     0.000003
#
#         DocPercent       IDF
# 0       100.000000 -0.000090
# 1       100.000000 -0.000090
# 2       100.000000 -0.000090
# 3       100.000000 -0.000090
# 4       100.000000 -0.000090
# ...            ...       ...
# 363130    0.008981  8.624612
# 363131    0.008981  8.624612
# 363132    0.008981  8.624612
# 363133    0.008981  8.624612
# 363134    0.008981  8.624612
#
# [363135 rows x 6 columns]

# %%
p = np.arange(0, 1, 0.001)
pv = word_info.DocPercent.quantile(p)

plt.figure(figsize=(12, 4))
plt.title("Word Document Percentage Percentiles")
plt.plot(p, pv)
plt.grid(1)
plt.xlabel("Percentile")
plt.ylabel("Word Document Percentage")
plt.show()

# %% [markdown]
# ## Look at Some Stats On Words
#
# There are so many words in the list. I am not sure that picking a range of those that fall into a doc percentage will give few enough words that TFIDF can be used well.

# %%
word_info[word_info.Word.isin({
    "rock",
    "country",
    "rap",
    "hop",
    "country",
    "jazz",
    "groove",
    "elvis",
    "nirvana",
    "psychadelic",
    "goodman"
})].sort_values(by='DocPercent', ascending=False)
# Out:
#          Word  WordCount  DocCount  WordPercent  DocPercent       IDF
# 48       rock      85723      8436     0.219932   75.767918  0.277377
# 146   country      29064      3466     0.074567   31.129872  1.166714
# 285      jazz      17374      2627     0.044575   23.594396  1.443780
# 464       hop      11811      2415     0.030302   21.690318  1.527890
# 570       rap       9715      1820     0.024925   16.346327  1.810618
# 1227    elvis       3704      1038     0.009503    9.322795  2.371745
# 2576   groove       1527       782     0.003918    7.023532  2.654626
# 2854  nirvana       1352       554     0.003469    4.975750  2.998791
# 3474  goodman       1060       505     0.002720    4.535657  3.091222

# %% [markdown]
# ## Doc2Vec
#
# Since the number of words is so large, I am looking to use doc2vec instead to control the number of features.

# %%
docs = []
for _, row in artists.iterrows():
    docs.append(TaggedDocument(row.DetailWords, [row.Artist]))

# %%
# %%time
doc_model = Doc2Vec(docs, vector_size=50, epochs=10)
# Out:
# 2021-10-30 18:21:18,026 - gensim.models.doc2vec - INFO - collecting all words and their counts
# 2021-10-30 18:21:18,029 - gensim.models.doc2vec - INFO - PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2021-10-30 18:21:22,335 - gensim.models.doc2vec - INFO - PROGRESS: at example #10000, processed 35069019 words (8144125/s), 342761 word types, 10000 tags
# 2021-10-30 18:21:22,906 - gensim.models.doc2vec - INFO - collected 363135 word types and 11134 unique tags from a corpus of 11134 examples and 38977116 words
# 2021-10-30 18:21:22,906 - gensim.models.word2vec - INFO - Creating a fresh vocabulary
# 2021-10-30 18:21:23,386 - gensim.utils - INFO - Doc2Vec lifecycle event {'msg': 'effective_min_count=5 retains 110427 unique words (30.40935189392375%% of original 363135, drops 252708)', 'datetime': '2021-10-30T18:21:23.386328', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-10-30 18:21:23,387 - gensim.utils - INFO - Doc2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 38561315 word corpus (98.93321763467569%% of original 38977116, drops 415801)', 'datetime': '2021-10-30T18:21:23.387330', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-10-30 18:21:23,928 - gensim.models.word2vec - INFO - deleting the raw counts dictionary of 363135 items
# 2021-10-30 18:21:23,935 - gensim.models.word2vec - INFO - sample=0.001 downsamples 32 most-common words
# 2021-10-30 18:21:23,936 - gensim.utils - INFO - Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 32374345.11704832 word corpus (84.0%% of prior 38561315)', 'datetime': '2021-10-30T18:21:23.936329', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-10-30 18:21:24,895 - gensim.models.word2vec - INFO - estimated required memory for 110427 words and 50 dimensions: 103837900 bytes
# 2021-10-30 18:21:24,896 - gensim.models.word2vec - INFO - resetting layer weights
# 2021-10-30 18:21:24,921 - gensim.utils - INFO - Doc2Vec lifecycle event {'msg': 'training model with 3 workers on 110427 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2021-10-30T18:21:24.921385', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-10-30 18:21:25,933 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 5.25% examples, 1542814 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:26,938 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 10.27% examples, 1567039 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:27,939 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 15.31% examples, 1578067 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:28,946 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 20.67% examples, 1587228 words/s, in_qsize 6, out_qsize 1
# 2021-10-30 18:21:29,949 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 25.91% examples, 1593630 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:30,949 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 31.15% examples, 1597015 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:31,950 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 36.27% examples, 1595622 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:32,951 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 41.75% examples, 1599862 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:33,953 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 46.25% examples, 1599003 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:34,959 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 51.28% examples, 1598622 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:35,963 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 56.68% examples, 1601037 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:36,965 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 61.61% examples, 1599551 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:37,966 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 66.36% examples, 1595869 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:38,967 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 71.41% examples, 1596270 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:39,969 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 76.81% examples, 1597285 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:40,974 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 82.03% examples, 1595651 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:41,975 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 87.75% examples, 1596015 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:21:42,980 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 92.93% examples, 1596199 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:43,983 - gensim.models.word2vec - INFO - EPOCH 1 - PROGRESS: at 98.38% examples, 1597968 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:21:44,238 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 18:21:44,242 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 18:21:44,245 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 18
- gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 18:24:25,660 - gensim.models.word2vec - INFO - EPOCH - 9 : training on 38977116 raw words (30866499 effective words) took 20.2s, 1529267 effective words/s
# 2021-10-30 18:24:26,666 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 5.11% examples, 1503255 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:27,668 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 9.94% examples, 1524950 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:28,672 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 14.76% examples, 1523680 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:29,673 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 19.71% examples, 1527110 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:30,677 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 24.82% examples, 1525323 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:31,681 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 29.02% examples, 1488461 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:32,683 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 33.62% examples, 1482288 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:33,686 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 39.05% examples, 1490107 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:24:34,689 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 43.60% examples, 1495106 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:24:35,692 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 48.01% examples, 1495169 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:36,694 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 52.82% examples, 1498028 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:24:37,702 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 57.80% examples, 1499632 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:38,707 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 62.72% examples, 1502964 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:24:39,714 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 67.57% examples, 1504081 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:40,719 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 72.22% examples, 1504023 words/s, in_qsize 6, out_qsize 0
# 2021-10-30 18:24:41,719 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 77.26% examples, 1503688 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:42,725 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 82.38% examples, 1505310 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:43,726 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 87.78% examples, 1506440 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:44,727 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 92.67% examples, 1507704 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:45,729 - gensim.models.word2vec - INFO - EPOCH 10 - PROGRESS: at 97.88% examples, 1509064 words/s, in_qsize 5, out_qsize 0
# 2021-10-30 18:24:46,120 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 2 more threads
# 2021-10-30 18:24:46,123 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 1 more threads
# 2021-10-30 18:24:46,130 - gensim.models.word2vec - INFO - worker thread finished; awaiting finish of 0 more threads
# 2021-10-30 18:24:46,131 - gensim.models.word2vec - INFO - EPOCH - 10 : training on 38977116 raw words (30867671 effective words) took 20.5s, 1508086 effective words/s
# 2021-10-30 18:24:46,132 - gensim.utils - INFO - Doc2Vec lifecycle event {'msg': 'training on 389771160 raw words (308665165 effective words) took 201.2s, 1534052 effective words/s', 'datetime': '2021-10-30T18:24:46.131159', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-10-30 18:24:46,132 - gensim.utils - INFO - Doc2Vec lifecycle event {'params': 'Doc2Vec(dm/m,d50,n5,w5,mc5,s0.001,t3)', 'datetime': '2021-10-30T18:24:46.132158', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# Wall time: 3min 28s

# %% [markdown]
# ## Save Model

# %%
os.makedirs("var/models", exist_ok=True)

# %%
doc_model.save("var/models/artist_detail_model.d2v")
# Out:
# 2021-10-30 18:24:46,162 - gensim.utils - INFO - Doc2Vec lifecycle event {'fname_or_handle': 'var/models/artist_detail_model.d2v', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-10-30T18:24:46.162166', 'gensim': '4.1.2', 'python': '3.7.6 (tags/v3.7.6:43364a7ae0, Dec 19 2019, 00:42:30) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'saving'}
# 2021-10-30 18:24:46,163 - gensim.utils - INFO - not storing attribute cum_table
# 2021-10-30 18:24:46,291 - gensim.utils - INFO - saved var/models/artist_detail_model.d2v

# %% [markdown]
# ## Extract Artist Embeddings

# %%
artists['DetailEmbedding'] = artists.DetailWords.apply(lambda words: doc_model.infer_vector(words))

# %% [markdown]
# ## Save Artist Embeddings

# %%
artists_save = artists[['Artist', 'ArtistLink', 'DetailEmbedding']].copy()
artists_save.DetailEmbedding = artists_save.DetailEmbedding.apply(lambda emb: ",".join(str(x) for x in emb))
artists_save.to_sql("artist_embedding", db, if_exists = 'replace', index = False)

# %%
cur = db.cursor()
cur.execute(f"""
   create unique index i_artist_embedding_artist on artist_embedding (Artist)
""")
db.commit()
cur.close()
